# %% [markdown]
# # Assignment 6

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" libraries (and any other libraries if you would like)

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read in the dataset named "features.csv".
# - Create a ``` lambda ``` function that checks if weight $≤$ 3000
# - Using the Pandas method ``.apply()``, create a new Series that shows ``True`` if weight $≤$ 3000 and ``False``if weight > 3000.
# - Using the ``.shape`` attribute, print the number of cars that have weight $≤$ 3000.
#
# **Hint**: A Pandas Series has only one dimension, so the ``.shape`` attribute is a "tuple" with only one element. In order to get a single integer, type ``your_variable_name.shape[0]``

# %%
# Write your answer here:
df = pd.read_csv("data/features.csv")
light = df["weight"].apply(lambda x: x <= 3000)
print(light.shape[0])
print(light.sum())
# Out:
# 398
# 230

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read in the dataset named "features.csv".
# - Define a global variable called ```threshold``` that takes the <br>
# value 2500
# - Subset the data to get one dataset with weight $>$ threshold and <br>
# another with weight $\le$ threshold. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets, printing these values to the screen<br>
#
# Note: Review how to define a global variable inside ```.query()```

# %%
# Write your answer here:
threshold = 2500

above_threshold = df.query("weight > @threshold")
below_or_equal_threshold = df.query("weight <= @threshold")

mean_above = above_threshold["acceleration"].mean()
mean_below_or_equal = below_or_equal_threshold["acceleration"].mean()


print("Mean acceleration (weight > 2500):", mean_above)
print("Mean acceleration (weight ≤ 2500):", mean_below_or_equal)
# Out:
# Mean acceleration (weight > 2500): 14.999601593625497
# Mean acceleration (weight ≤ 2500): 16.53877551020408

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column <br>
# from oldest to youngest
# - Get a subset with the 5 oldest players

# %%
# Write your answer here:

df = pd.read_csv("fifa23_playerscopy.csv")
df_sorted = df.sort_values("Age", ascending=False)
oldest_five = df_sorted.iloc[:5]
print(oldest_five)
# Out:
#        Unnamed: 0     Known As          Full Name  Overall  Potential  \
# 592           592    G. Buffon   Gianluigi Buffon       79         79
# 13548       13548     S. Lukić       Stojan Lukić       62         62
# 3276         3276   S. Torrico  Sebastián Torrico       72         72
# 15525       15525  J. Szmatuła     Jakub Szmatuła       59         59
# 10851       10851    M. Galezo      Moisés Galezo       64         64
#
#        Value(in Euro) Positions Played Best Position             Nationality  \
# 592           1900000               GK            GK                   Italy
# 13548           45000               GK            GK  Bosnia and Herzegovina
# 3276           250000               GK            GK               Argentina
# 15525           25000               GK            GK                  Poland
# 10851               0               CB            CB               Venezuela
#
#                                              Image Link  ...  Preferred Foot  \
# 592    https://cdn.sofifa.net/players/001/179/23_60.png  ...           Right
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png  ...           Right
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png  ...           Right
# 15525  https://cdn.sofifa.net/players/155/422/23_60.png  ...           Right
# 10851  https://cdn.sofifa.net/players/265/721/23_60.png  ...           Right
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 592                   2            1                         4
# 13548                 2            1                         1
# 3276                  2            1                         1
# 15525                 3            1                         1
# 10851                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 592                     -  https://cdn.sofifa.net/flags/it.png
# 13548                   -                                    -
# 3276                    -  https://cdn.sofifa.net/flags/ar.png
# 15525                   -  https://cdn.sofifa.net/flags/pl.png
# 10851                   -  https://cdn.sofifa.net/flags/ve.png
#
#        National Team Position  National Team Jersey Number  \
# 592                         -                            -
# 13548                       -                            -
# 3276                        -                            -
# 15525                       -                            -
# 10851                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 592                Medium              Medium
# 13548              Medium              Medium
# 3276               Medium              Medium
# 15525              Medium              Medium
# 10851              Medium                High
#
# [5 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Weight(in kg)"
# and store it as a variable
# - Subset the players whose Weight in kilograms is stricly large than this mean value
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for when using column names inside the .query() method (the backtick `)

# %%
# Write your answer here:
mean_weight = df["Weight(in kg)"].mean()
heavier_players = df.query("`Weight(in kg)` > @mean_weight")
print(heavier_players)
# Out:
#        Unnamed: 0           Known As                     Full Name  Overall  \
# 1               1         K. Benzema                 Karim Benzema       91
# 2               2     R. Lewandowski            Robert Lewandowski       91
# 6               6        T. Courtois              Thibaut Courtois       90
# 7               7           M. Neuer                  Manuel Neuer       90
# 8               8  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90
# ...           ...                ...                           ...      ...
# 18492       18492          H. Tiwari                Hrithik Tiwari       49
# 18501       18501      Deng Xiongtao                 Xiongtao Deng       48
# 18507       18507            M. Khan            Muheet Shabir Khan       48
# 18508       18508          L. Jongte            Lalbiakhlua Jongte       48
# 18524       18524         A. Brînzea                Andreș Brînzea       48
#
#        Potential  Value(in Euro) Positions Played Best Position Nationality  \
# 1             91        64000000            CF,ST            CF      France
# 2             91        84000000               ST            ST      Poland
# 6             91        90000000               GK            GK     Belgium
# 7             90        13500000               GK            GK     Germany
# 8             90        41000000               ST            ST    Portugal
# ...          ...             ...              ...           ...         ...
# 18492         63          100000               GK            GK       India
# 18501         61          100000               GK            GK    China PR
# 18507         61          100000               GK            GK       India
# 18508         60          100000               GK            GK       India
# 18524         72          130000               GK            GK     Romania
#
#                                              Image Link  ...  Preferred Foot  \
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...            Left
# 7      https://cdn.sofifa.net/players/167/495/23_60.png  ...           Right
# 8      https://cdn.sofifa.net/players/020/801/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18492  https://cdn.sofifa.net/players/265/460/23_60.png  ...           Right
# 18501  https://cdn.sofifa.net/players/269/526/23_60.png  ...           Right
# 18507  https://cdn.sofifa.net/players/259/562/23_60.png  ...           Right
# 18508  https://cdn.sofifa.net/players/259/313/23_60.png  ...            Left
# 18524  https://cdn.sofifa.net/players/271/179/23_60.png  ...           Right
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 1                     4            4                         4
# 2                     4            4                         5
# 6                     3            1                         4
# 7                     4            1                         5
# 8                     4            5                         5
# ...                 ...          ...                       ...
# 18492                 3            1                         1
# 18501                 3            1                         1
# 18507                 2            1                         1
# 18508                 3            1                         1
# 18524                 2            1                         1
#
#        National Team Name             National Team Image Link  \
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 6                 Belgium  https://cdn.sofifa.net/flags/be.png
# 7                 Germany  https://cdn.sofifa.net/flags/de.png
# 8                Portugal  https://cdn.sofifa.net/flags/pt.png
# ...                   ...                                  ...
# 18492                   -                                    -
# 18501                   -                                    -
# 18507                   -                                    -
# 18508                   -                                    -
# 18524                   -  https://cdn.sofifa.net/flags/ro.png
#
#        National Team Position  National Team Jersey Number  \
# 1                          ST                           19
# 2                          ST                            9
# 6                          GK                            1
# 7                          GK                            1
# 8                          ST                            7
# ...                       ...                          ...
# 18492                       -                            -
# 18501                       -                            -
# 18507                       -                            -
# 18508                       -                            -
# 18524                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 1                  Medium              Medium
# 2                    High              Medium
# 6                  Medium              Medium
# 7                  Medium              Medium
# 8                    High                 Low
# ...                   ...                 ...
# 18492              Medium              Medium
# 18501              Medium              Medium
# 18507              Medium              Medium
# 18508              Medium              Medium
# 18524              Medium              Medium
#
# [8411 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Plot by Category
#
# <font size = "3">
#
# Read in the dataset named "wdi_urban.csv".
#
#   This contains data from 1980 and 2020.
#
# - **Create an array with the unique values of "year" using the ``Pandas`` function ``unique``**
#
# - **Create a plot with a ...**
#     - Histogram of "prop_urbanpopulation" (proportion of urban population) for each year
#     - Set the histogram option `alpha = 0.5` for transparency
#     - All the histograms should be overlapping on the same plot
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# **Hint**: The procedure will be similar (but not exactly the same!) as when we created a scatter plot of cars with different numbers of cylinders in Lecture 11

# %%
# your answer here
df = pd.read_csv("wdi_urban.csv") #COULD NOT FIND WHICH FOLDER THIS DATA WAS IN

years = df["year"].unique()

for y in years:
    subset = df[df["year"] == y]
    plt.hist(subset["prop_urbanpopulation"], alpha=0.5, label=str(y))

plt.xlabel("Proportion of Urban Population")
plt.ylabel("Frequency")
plt.title("Distribution of Urban Population Proportion by Year")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # your answer here
# ----> 2 df = pd.read_csv("wdi_urban.csv")
#       4 years = df["year"].unique()
#       6 for y in years:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wdi_urban.csv'
